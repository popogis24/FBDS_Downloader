# %%
import requests

def get_data():
    data = {
        'action': 'download',  # Include the 'action' parameter
        'as': 'APP.tar',
        'type': 'php-tar',
        'baseHref': '/AC/ACRELANDIA/',
        'hrefs': '',
        'hrefs[0]': '/AC/ACRELANDIA/APP/'  # Make sure the 'hrefs[0]' parameter is correctly formatted
    }
    response = requests.post('https://geo.fbds.org.br/AC/ACRELANDIA/', json=data)
    if response.status_code == 200:
        with open('APP.tar', 'wb') as f:
            f.write(response.content)
    print(response.status_code)

get_data()
# Out:
# 200

# %%
import os
print(os.__file__)
# Out:
# /opt/homebrew/Cellar/python@3.12/3.12.3/Frameworks/Python.framework/Versions/3.12/lib/python3.12/os.py

# %% [markdown]
# import os
# print(os.__file__
# )

# %%
dict_of_files = {
    'PI': {
        'ALTOS': ['APP', 'HIDROGRAFIA'],
        'BRASILEIRA': ['APP', 'HIDROGRAFIA'],
        'BURITI_DOS_MONTES': ['APP', 'HIDROGRAFIA'],
        'CAMPO_MAIOR': ['APP', 'HIDROGRAFIA'],
        'CASTELO_DO_PIAUI': ['APP', 'HIDROGRAFIA'],
        'COIVARAS': ['APP', 'HIDROGRAFIA'],
        'JUAZEIRO_DO_PIAUI': ['APP', 'HIDROGRAFIA'],
        'PAU_DARCO_DO_PIAUI': ['APP', 'HIDROGRAFIA'],
        'PIRIPIRI': ['APP', 'HIDROGRAFIA'],
        'SAO_JOAO_DA_FRONTEIRA': ['APP', 'HIDROGRAFIA'],
        'SIGEFREDO_PACHECO': ['APP', 'HIDROGRAFIA'],
        'TERESINA': ['APP', 'HIDROGRAFIA'],
    },
    'CE': {
        'BOA_VIAGEM': ['APP', 'HIDROGRAFIA'],
        'CRATEUS': ['APP', 'HIDROGRAFIA'],
        'IBIAPINA': ['APP', 'HIDROGRAFIA'],
        'MONSENHOR_TABOSA': ['APP', 'HIDROGRAFIA'],
        'QUIXADA': ['APP', 'HIDROGRAFIA'],
        'QUIXERAMOBIM': ['APP', 'HIDROGRAFIA'],
        'TAMBORIL': ['APP', 'HIDROGRAFIA'],
        'UBAJARA': ['APP', 'HIDROGRAFIA'],
    }
}
